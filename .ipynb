# %%
from collections import Counter

# %%
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup
import re

# %%
userURL = input("Enter the url to the desired page to download")
print(userURL)#working to here.
try:
    with urllib.request.urlopen(userURL) as doc:
        html = doc.read()
except:
    print("Couldnt open %s" % doc, file = sys.err)
# Out:
# Enter the url to the desired page to downloadhttps://animaldiversity.org/accounts/Lepomis_microlophus/
# https://animaldiversity.org/accounts/Lepomis_microlophus/

# %%
wrdCnt = Counter(html.split())
wrdCnt.most_common()
# Out:
# [(b'<a', 177),
#  (b'</li>', 124),
#  (b'<li>', 123),
#  (b'and', 110),
#  (b'of', 86),
#  (b'<span', 77),
#  (b'the', 76),
#  (b'<div', 73),
#  (b'</div>', 70),
#  (b'to', 67),
#  (b'</dl>', 57),
#  (b'<dl>', 56),
#  (b'in', 54),
#  (b'</ul>', 50),
#  (b'<p', 48),
#  (b'</dd>', 45),
#  (b'class="gloss"', 43),
#  (b'<dd>', 42),
#  (b'sunfish', 40),
#  (b'are', 34),
#  (b'/>', 33),
#  (b'(<a', 31),
#  (b'</p>', 31),
#  (b'<ul', 30),
#  (b'donthyphenate', 24),
#  (b'a', 22),
#  (b'class="feature', 22),
#  (b'rel="tooltip"', 22),
#  (b'for', 21),
#  (b'that', 21),
#  (b'at', 21),
#  (b'<ul>', 20),
#  (b'class="citations">', 20),
#  (b'<li', 19),
#  (b'on', 18),
#  (b'as', 18),
#  (b'class="keywords', 18),
#  (b'style="font-style:', 18),
#  (b'class="feature-off', 18),
#  (b'<section', 17),
#  (b'<h3', 17),
#  (b'</section>', 17),
#  (b'class="hyphenate">', 16),
#  (b'their', 16),
#  (b'pictures', 16),
#  (b'or', 15),
#  (b'by', 15),
#  (b'class="taxon-link', 15),
#  (b'<meta', 14),
# ...
